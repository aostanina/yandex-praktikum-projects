# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Общая информация</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Замена-названий-столбцов" data-toc-modified-id="Замена-названий-столбцов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Замена названий столбцов</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Преобразование-данных-в-нужные-типы" data-toc-modified-id="Преобразование-данных-в-нужные-типы-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Преобразование данных в нужные типы</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Сколько-игр-выпускалось-в-разные-годы?" data-toc-modified-id="Сколько-игр-выпускалось-в-разные-годы?-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Сколько игр выпускалось в разные годы?</a></span></li><li><span><a href="#Как-менялись-продажи-по-платформам?" data-toc-modified-id="Как-менялись-продажи-по-платформам?-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Как менялись продажи по платформам?</a></span></li><li><span><a href="#Какие-платформы-лидируют-по-продажам,-растут-или-падают?" data-toc-modified-id="Какие-платформы-лидируют-по-продажам,-растут-или-падают?-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Какие платформы лидируют по продажам, растут или падают?</a></span></li><li><span><a href="#График-&quot;ящик-с-усами&quot;-по-глобальным-продажам-игр-в-разбивке-по-платформам" data-toc-modified-id="График-&quot;ящик-с-усами&quot;-по-глобальным-продажам-игр-в-разбивке-по-платформам-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>График "ящик с усами" по глобальным продажам игр в разбивке по платформам</a></span></li><li><span><a href="#Как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков?" data-toc-modified-id="Как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков?-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков?</a></span></li><li><span><a href="#Как-влияют-на-продажи-на-остальные-платформы-отзывы-пользователей-и-критиков?" data-toc-modified-id="Как-влияют-на-продажи-на-остальные-платформы-отзывы-пользователей-и-критиков?-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Как влияют на продажи на остальные платформы отзывы пользователей и критиков?</a></span></li><li><span><a href="#Распределение-игр-по-жанрам" data-toc-modified-id="Распределение-игр-по-жанрам-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Распределение игр по жанрам</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Портрет-пользователя-каждого-региона" data-toc-modified-id="Портрет-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Портрет пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Самые-популярные-платформы-(топ-5)" data-toc-modified-id="Самые-популярные-платформы-(топ-5)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Самые популярные платформы (топ-5)</a></span></li><li><span><a href="#Самые-популярные-жанры-(топ-5)" data-toc-modified-id="Самые-популярные-жанры-(топ-5)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Самые популярные жанры (топ-5)</a></span></li><li><span><a href="#Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?" data-toc-modified-id="Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Влияет ли рейтинг ESRB на продажи в отдельном регионе?</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-1:-&quot;Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые&quot;" data-toc-modified-id="Гипотеза-1:-&quot;Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые&quot;-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Гипотеза 1: "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые"</a></span></li><li><span><a href="#Гипотеза-2:-&quot;Средние-пользовательские-рейтинги-жанров-Action-и-Sports-разные&quot;" data-toc-modified-id="Гипотеза-2:-&quot;Средние-пользовательские-рейтинги-жанров-Action-и-Sports-разные&quot;-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Гипотеза 2: "Средние пользовательские рейтинги жанров Action и Sports разные"</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Изучение закономерностей, определяющих успешность игр

# %% [markdown]
# # Описание проекта
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# **Описание данных**
# Name — название игры
# Platform — платформа
# Year_of_Release — год выпуска
# Genre — жанр игры
# NA_sales — продажи в Северной Америке (миллионы проданных копий)
# EU_sales — продажи в Европе (миллионы проданных копий)
# JP_sales — продажи в Японии (миллионы проданных копий)
# Other_sales — продажи в других странах (миллионы проданных копий)
# Critic_Score — оценка критиков (максимум 100)
# User_Score — оценка пользователей (максимум 10)
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %%
# импортируем необходимые библиотеки
from IPython.display import display
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as st
import seaborn as sns

# отключаем предупреждения фильтрации
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Общая информация

# %%
# загружаем датасет
data = pd.read_csv('/datasets/games.csv')

# выводим общую информацию для изучения
display(data.info(memory_usage='deep'))
display(data.head())
display(data.describe().T)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 5.6 MB
# None
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Можно заметить следующие особенности в столбцах:
#
# Name - 2 пропуска из всего датасета
# Year_of_Release - 269 пропусков. Столбец имеет неверный тип данных.
# Genre - 2 пропуска из всего датасета.
# NA_sales, EU_sales, JP_sales, Other_sales - имеют избыточный тип данных.
# Critic_Score - 8578 пропусков. Столбец имеет избыточный тип данных.
# User_Score - 6701 пропусков. Столбец имеет избыточный тип данных.
# Rating - 6766 пропусков.
#
# В датасете 5 качественных и 6 количественных параметров.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Замена названий столбцов

# %%
# Приведём названия столбцов к нижнему регистру
data.columns = data.columns.str.lower()

# проверяем результат
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16713 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null float64
# genre              16713 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       8137 non-null float64
# user_score         10014 non-null object
# rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# None

# %% [markdown]
# Замена названий столбцов осуществлена успешно.

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# Для того, чтобы в дальнейшем успешно выполнить поставленные задачи, нужно заполнить пропуски в данных.
#
# Пропуски в столбцах year_of_release, critic_score, user_score логично заполнить индикаторным значением (например, -1), так их потом будет легче фильтровать при исследовании выборок. Для столбцов critic_score, user_score также заменим значение tbd на -1.
# Заполнять данные столбцы медианой или средним не будем, чтобы не влиять на результаты исследования, а для столбца с годом выпуска - это  бессмысленно.
# Заполнить пропуском нулём также нельзя, чтобы не искажать данные столбцов, которые могут принимать нулеввые значения.
#
# Пропуски в столбце rating (равно как и значение tbd) мы заполним индикаторным значением RP (Rating Pending), которое является официальным значением рейтинга ESRB, присваиваемое в случае, когда с рейтингом ещё не определились (см. https://www.esrb.org/ratings-guide/).
#
# В столбцах name и genre всего по два пропуска, и их мы также заполним индикаторными значениями unnamed_game и untitled_genre, соответственно.

# %%
# заполняем пропуски
data.fillna(value={'name':'unnamed_game',
                   'year_of_release':-1,
                   'genre':'untitled_genre',
                   'critic_score':-1,
                   'user_score':-1.0,
                   'rating':'RP'}, inplace=True)

# обрабатываем значение tbd
for i in ['critic_score', 'user_score']:
    data.loc[data[i] == 'tbd', i] = -1.0
   

# смотрим на результат
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16715 non-null object
# platform           16715 non-null object
# year_of_release    16715 non-null float64
# genre              16715 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       16715 non-null float64
# user_score         16715 non-null object
# rating             16715 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# None

# %% [markdown]
# Теперь датасет избавлен от пропусков.

# %% [markdown]
# ### Преобразование данных в нужные типы

# %% [markdown]
# Для автоматизации преобразования сначала составим словарь, в котором сопоставим столбцу необходимый тип данных, а после этого выполним преобразование данных в цикле. Но для начала нужно разобраться, какие типы нам нужны для наших столбцов:
#
# столбец year_of_release - тип данных int16;
# столбцы na_sales, eu_sales, jp_sales, other_sales - тип данных float16;
# столбец critic_score - тип данных int8;
# столбец user_score - тип данных float16.

# %%
# составим словарь с новыми типами данных
new_types = {
    'year_of_release':'int16',
    'na_sales':'float16',
    'eu_sales':'float16',
    'jp_sales':'float16',
    'other_sales':'float16',
    'critic_score':'int8',
    'user_score':'float16'}

# приводим данные к новым типам
for i in new_types.keys():
    try:
        data[i] = data[i].astype(new_types[i], errors='ignore')
    except:
        print(f'Приведение типов не удалось, проверьте данные в столбце {i}')

# смотрим на результат
display(data.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16715 non-null object
# platform           16715 non-null object
# year_of_release    16715 non-null int16
# genre              16715 non-null object
# na_sales           16715 non-null float16
# eu_sales           16715 non-null float16
# jp_sales           16715 non-null float16
# other_sales        16715 non-null float16
# critic_score       16715 non-null int8
# user_score         16715 non-null float16
# rating             16715 non-null object
# dtypes: float16(5), int16(1), int8(1), object(4)
# memory usage: 4.4 MB
# None

# %% [markdown]
# Приведение типов проведено успешно.
#
# Проведем также проверку данных на наличие дубликатов.

# %%
print(f'Количество дубликатов в таблице: {data.duplicated().sum()}')
# Out:
# Количество дубликатов в таблице: 0

# %% [markdown]
# Дубликатов нет. Теперь можно переходить к расчёту суммарных продаж по всем регионам.

# %%
# просуммируем продажи со всех регионов
data['total_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales']

# выведем результаты 
display(data.describe().T)
display(data.head(10))
# Out:
#                    count         mean         std  min          25%  \
# year_of_release  16715.0  1974.177505  252.685735 -1.0  2003.000000
# na_sales         16715.0     0.263184    0.813477  0.0     0.000000
# eu_sales         16715.0     0.145020    0.502930  0.0     0.000000
# jp_sales         16715.0     0.077637    0.308838  0.0     0.000000
# other_sales      16715.0     0.047333    0.186768  0.0     0.000000
# critic_score     16715.0    33.060844   36.299555 -1.0    -1.000000
# user_score       16715.0     2.689453    4.171875 -1.0    -1.000000
# total_sales      16715.0     0.533203    1.547852  0.0     0.059998
#
#                          50%          75%          max
# year_of_release  2007.000000  2010.000000  2016.000000
# na_sales            0.080017     0.239990    41.375000
# eu_sales            0.020004     0.109985    28.953125
# jp_sales            0.000000     0.040009    10.218750
# other_sales         0.010002     0.029999    10.570312
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Мы успешно привели названия столбцов к нижнему регистру, преобразовали данные к нужному типу, заполнили пропуски в данных и проверили датасет на наличие дубликатов. Данные готовы к анализу.
#
# Возможные причины появления пропусков:
#
# для столбцов с незначительным количеством пропусков - это, скорее всего, техническая ошибка при подготовке данных.
# для столбцов со значительным количеством пропусков причины можно выделить следующие:
# техническая возможность - например, для игр выпуска до 1994 рейтинг ESRB в принципе не может существовать, ввиду отсутствие на тот момент самой организации. То же самое и для пользовательских рейтингов и оценок критиков - на тот момент сбор таких данных не был унифицирован и не было площадки для их сбора.
# Также не стот забывать о том, что написание рецензии и рейтинга - это необязательные действия для игроков.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Сколько игр выпускалось в разные годы?

# %%
# посмотрим на количество игр, выпущенных в разные годы, предварительно отфильтровав индикаторные значения
_data = data[data['year_of_release'] > 0]
display(_data.pivot_table(index='year_of_release', aggfunc={'name':'count'}))
# Out:
#                  name
# year_of_release
# 1980                9
# 1981               46
# 1982               36
# 1983               17
# 1984               14
# 1985               14
# 1986               21
# 1987               16
# 1988               15
# 1989               17
# 1990               16
# 1991               41
# 1992               43
# 1993               62
# 1994              121
# 1995              219
# 1996              263
# 1997              289
# 1998              379
# 1999              338
# 2000              350
# 2001              482
# 2002              829
# 2003              775
# 2004              762
# 2005              939
# 2006             1006
# 2007             1197
# 2008             1427
# 2009             1426
# 2010             1255
# 2011             1136
# 2012              653
# 2013              544
# 2014              581
# 2015              606
# 2016              502

# %%
# посмотрим на те же данные, но уже в виде графика
ax = _data.pivot_table(index='year_of_release',aggfunc={'name':'count'}).reset_index().plot(x='year_of_release',
                                                                                            y='name',            
                                                                                            figsize=(12,6),
                                                                                            title='Распределение изданных игр по годам (данные за 1980 - 2016 гг.)',
                                                                                            grid=True,
                                                                                            legend=False,
                                                                                            style='o-')
ax.set_xlabel('Год издания')
ax.set_ylabel('Кол-во изданных игр')
# Out:
# Text(0, 0.5, 'Кол-во изданных игр')

# %% [markdown]
# Распределение изданных игр показывает наглядно, что для анализа нужны не все данные. Так, данные с 1980 по 1994 год можно не принимать в расчет.
#
# Видим, что большое количество игр выпущено в промежуток с 2007 по 2010 год, пик был достигнут в 2008 и в 2009 годах, когда ежегодно выпусклось более 1410 игр.
#
# К 2013 году число выпущенных игр идет на спад (снижается до 550), немного растет к 2015 году до 600, потом вновь идет на понижение.
#
# Для прогноза на 2017 год едва ли будут полезны данные за 1990, когда рынок был совершенно другой и не было той технической базы, котора была уже в начале нулевых.
#
# Сейчас же индустрия геймдев считается одной из наиболее перспективной для будущих программистов и визуализаторов. Связано это не только с последствиями пандемии, запершей большинство населения по домам со своими гаджетами, но и с развитием графического дизайна.

# %% [markdown]
# ### Как менялись продажи по платформам?

# %%
# посмотрим на суммарные продажи по платформам и выберем несколько с наибольшими суммами продаж
display(data.pivot_table(index='platform', aggfunc={'total_sales':'sum'}).sort_values(by='total_sales', ascending=False))
# Out:
#           total_sales
# platform
# PS2       1256.000000
# X360       971.500000
# PS3        939.500000
# Wii        907.500000
# DS         806.000000
# PS         731.000000
# GBA        317.750000
# PS4        314.250000
# PSP        294.000000
# PC         259.500000
# 3DS        259.000000
# XB         257.750000
# GB         255.500000
# NES        251.000000
# N64        218.625000
# SNES       200.000000
# GC         199.000000
# XOne       159.250000
# 2600        96.937500
# WiiU        82.187500
# PSV         54.062500
# SAT         33.593750
# GEN         30.765625
# DC          15.945312
# SCD          1.860352
# NG           1.439453
# WS           1.419922
# TG16         0.160034
# 3DO          0.099976
# GG           0.040009
# PCFX         0.029999

# %% [markdown]
# Определили платформы с наибольшими суммарными продажами, это: PlayStation 2, Xbox 360, PlayStation 3, Wii, Nintendo DS и классический PlayStation.
# Построим распределение продаж по этим платформам по годам.

# %%
# напишем функцию для вывода графика
def chart(_data,_platform):
    _title='Распределение продаж на платформе '+_platform+' по годам (данные за '+str(_data.index.min())+'-'+str(_data.index.max())+' гг)'
    ax=_data.reset_index().plot(x='year_of_release',
                                              y='total_sales',
                                              figsize=(12,6),
                                              title=_title,
                                              grid=True,
                                              legend=False,
                                              style='o-')
    ax.set_xlabel('Год издания')
    ax.set_ylabel('Кол-во проданных копий, млн. шт')
    plt.show()

# в цикле выведем таблицу и графики изменения продаж по нашим лидерам
for i in ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS']:
    local_pivot = data.query('(year_of_release > 0) and (platform == @i)').pivot_table(index='year_of_release', aggfunc={'total_sales':'sum'})
    display(local_pivot)
    chart(local_pivot, i)
# Out:
#                  total_sales
# year_of_release
# 2000               39.156250
# 2001              166.375000
# 2002              205.375000
# 2003              184.375000
# 2004              211.750000
# 2005              160.625000
# 2006              103.437500
# 2007               76.000000
# 2008               53.906250
# 2009               26.406250
# 2010                5.640625
# 2011                0.449951
#                  total_sales
# year_of_release
# 2005                8.250000
# 2006               51.625000
# 2007               95.375000
# 2008              135.250000
# 2009              120.250000
# 2010              170.000000
# 2011              143.875000
# 2012               99.750000
# 2013               88.562500
# 2014               34.750000
# 2015               11.960938
# 2016                1.520508
#                  total_sales
# year_of_release
# 2006               20.968750
# 2007               73.187500
# 2008              118.500000
# ...

# %% [markdown]
# Изучим изменение прибыли от выпущенных игр по годам в разбивке по платформам.

# %%
import seaborn as sns

plt.figure(figsize=(14,12))
sns.set(style="ticks")
sns.lineplot(data = data.groupby(['year_of_release', 'platform']).agg({'total_sales': 'sum'}).reset_index(),
             x = 'year_of_release', y = 'total_sales', hue = 'platform', marker="o", palette="bright")

plt.xlabel('Год выхода игр')
plt.ylabel('Млн проданных копий игр')
plt.suptitle("Распределение продаж по годам в зависимости от платформы")
plt.grid()
plt.xticks(np.arange(1995, 2017, 1)) #зададим шаг по ox
plt.yticks(np.arange(0, 225, 25)) #зададим шаг по oy
plt.ylim(-5, 225)
plt.xlim(1995, 2018)
# Out:
# (1995, 2018)

# %% [markdown]
# Из всей наблюдаемой на графике динамики, видим, что продажи по всем платформам идут на спад. Для 2016 года мы не можем сделать определнный вывод, тк данные по нему неполные.
#
# Исходя из полученных данных, можно сказать, что средний срок жизни платформы - 8 лет.
# По графику общих продаж по всем платформам видно, что последний рост продаж начался в 2013 году, т.е. именно с этого срока и имеет смысл брать данные. Т.е. актуальный период данных составляет 2013-2016 гг. Больший срок для такой инновационной отсрали был бы избыточен, так как здесь каждый год происхождят революции.

# %%
# Сделаем срез с данными за актуальный период и сохраним его в новую переменную для удобства работы
actual_data = data.query('year_of_release >= 2013')

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают?

# %%
# запишем список актуальных платформ
actual_platforms = list(actual_data['platform'].unique())

# посмотрим на суммарные продажи по актуальным платформам
display(actual_data.pivot_table(index='platform', aggfunc={'total_sales':'sum'}).sort_values(by='total_sales', ascending=False))
# Out:
#           total_sales
# platform
# PS4        314.250000
# PS3        181.500000
# XOne       159.250000
# 3DS        143.250000
# X360       136.750000
# WiiU        64.625000
# PC          39.437500
# PSV         33.000000
# Wii         13.664062
# PSP          3.500000
# DS           1.540039

# %% [markdown]
# Первые пять мест делят два поколения PlayStation (PS4, PS3), два поколения Xbox (XOne, X360) и Nintendo (3DS). Видно, что четвертое поколение PlayStation обгоняет третье по продажам почти в 2 раза, тогда как разница в продажах Xbox незначительная. Посмотрим на графики изменения продаж для каждой из актуальных платформ.

# %%
# построим графики в цикле
for i in actual_platforms:
    local_pivot = actual_data.query('platform == @i').pivot_table(index='year_of_release', aggfunc={'total_sales':'sum'})
    chart(local_pivot, i)

# %% [markdown]
# Построим общий график с данными продаж по платформам в актуальном периоде.

# %%
pd.pivot_table(
    actual_data, values = 'total_sales', index = 'platform', aggfunc = np.sum
    ).sort_values(
        'total_sales', ascending=False
        ).plot(
                kind='bar', title='Продажи по платформам', figsize=(10,10), colormap='Reds_r'
                )
plt.grid()
plt.xlabel('Платформа')
plt.ylabel('Суммарные продажи')
plt.show()

# %% [markdown]
# На этом графике хорошо заметно платформы-лидеры суммарных продаж. Это PS4, PS3, XOne, 3DS и X360.

# %%
# более наглядно представим платформы в общем графике
plt.figure(figsize=(14,12))
sns.lineplot(data = actual_data.groupby(['year_of_release', 'platform']).agg({'total_sales': 'sum'}).reset_index(),
             x = 'year_of_release', y = 'total_sales', hue = 'platform', marker="o", palette="bright")

plt.xlabel('Год выхода игр')
plt.ylabel('Млн проданных копий игр')
plt.suptitle("Распределение продаж по годам в зависимости от платформы")
plt.grid()
plt.xticks([2013, 2014, 2015, 2016])
#plt.xticks(np.arange(1995, 2017, 1)) #зададим шаг по ox
plt.yticks(np.arange(0, 120, 5)) #зададим шаг по oy
#plt.ylim(-5, 200)
#plt.xlim(1995,)
plt.show()

# %% [markdown]
# Графики показали следующее:
#
# Лидируют по продажам следующие платформы:
# - PS4
# - PS3
# - XOne
# - 3DS
# - X360
#
# Учитывая, что данные за 2016-й год могут быть неполными, можно сказать, что растут следующие платформы:
# - PS4
# - XOne
#
# Предположительно к 2017 году эти платформы должны достигнуть пика продаж (принимая в расчет продолжительность жизненного цикла платформ в 8 лет).
#
# Падают в плане продаж следующие платформы:
# - PS3
# - X360
# - 3DS
# - WiiU
# - Wii
# - PC
# - PSV
# - DS
# - PSP
#
# Потенциально прибыльными в 2017 году для нас будут:
# - PS4
# - XOne
# - платформы, которые все ещё показывают значимые продажи: PS3, X360, 3DS, WiiU, PSV

# %% [markdown]
# ### График "ящик с усами" по глобальным продажам игр в разбивке по платформам

# %%
# построим боксплоты  по платформам (по оси X будут платформы)
actual_data.boxplot('total_sales', by = 'platform')
#зададим лимит для оси 0Y
plt.ylim(-0.5, 2)
# Out:
# (-0.5, 2)

# %% [markdown]
# Если избавиться от выбросов в выборках по продажам на каждой из платформ, то получится, что X360, PS4 и Wii идут вровень. Чуть уступают им XOne и WiiU. 3DS уже не входит в пятёрку лидеров, в которую он попал только за счёт выбросов.

# %% [markdown]
# ### Как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков?

# %%
# напишем функцию для вывода диаграмм рассеяния
def scatter(_data, _xname, _yname, _title, _xlabel):
    ax = _data.plot.scatter(_xname,
                            _yname,
                            figsize=(12,8),
                            grid=True)
    ax.set_title(_title)
    ax.set_xlabel(_xlabel)
    ax.set_ylabel('Кол-во проданных копий, млн. шт')
    plt.show()
    
# напишем функцию для изучения влияния рейтингов на продажи
def score_influence(_platform):
    title=f'Зависимость суммарных продаж от пользовательского рейтинга (данные для платформы {_platform} за 2013-2016 гг)'
    xlabel='Пользовательский рейтинг (0-10 баллов)'
    local_data = actual_data.query('(platform == @_platform) and (user_score.notna()) and (user_score > 0)')
    scatter(local_data, 'user_score', 'total_sales', title, xlabel) 
    corr = round(local_data['total_sales'].corr(local_data['user_score']), 2)
    print(f'Коэффициент корреляции между пользовательским рейтингом и суммарными продажами составляет {corr}')
    title=f'Зависимость суммарных продаж от рейтинга критиков (данные для платформы {_platform} за 2013-2016 гг)'
    xlabel='Рейтинг критиков (0-100 баллов)'
    local_data = actual_data.query('(platform == @_platform) and (critic_score.notna()) and (critic_score > 0)')
    scatter(local_data, 'user_score', 'total_sales', title, xlabel)
    corr = round(local_data['total_sales'].corr(local_data['critic_score']), 2)
    print(f'Коэффициент корреляции между рейтингом критиков и суммарными продажами составляет {corr}')

# оценим влияние для платформы-лидера продаж PS4 
score_influence('PS4')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# Коэффициент корреляции между пользовательским рейтингом и суммарными продажами составляет -0.03
# Коэффициент корреляции между рейтингом критиков и суммарными продажами составляет 0.41

# %% [markdown]
# Исходя из полученных данных по платформе PS4 можно сделать следующие выводы:
#
# - зависимость между пользовательским рейтингом и суммарными продажами либо отсутствует вовсе, либо её характер нелинейный
# - зависимость между рейтингом критиков и суммарными продажами присутствует, она явно выражена
#
# Посмотрим на графики зависимостей по другим платформам.

# %% [markdown]
# ### Как влияют на продажи на остальные платформы отзывы пользователей и критиков?

# %%
actual_platforms[0:6]
# Out:
# ['PS3', 'X360', 'PS4', '3DS', 'XOne', 'WiiU']

# %%
for i in actual_platforms[0:6]:
    if i != 'PS4':
        score_influence(i)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# Коэффициент корреляции между пользовательским рейтингом и суммарными продажами составляет 0.0
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# По топ-5 (по продажам) платформам влияние отзывов на продажи следующие:
#
# - зависимость между рейтингом критиков и суммарными продажами можно считать высокой и примерно одинаковой для всех платформ. Коэффициент корреляции по всем платформам равен (с небольшими отклонениями) около 0,38 (для PS3 - 0,33; X360 - 0,35; 3DS - 0,36; XOne - 0,42; WiiU - 0,38).
# - зависимость между пользовательским рейтингом и суммарными продажами для разных платформ отличается:
# а) для PS3, X360, XOne ситуация псхожая с PS4 - зависимость либо нулевая, либо отрицательная форма. Вероятная прчина: из-за высокой стоимости этих игр пользователи опираются на мнение профессионалов (критиков), а не мнении пользователей;
# б) 3DS показывает зависимость продаж от пользовательского рейтинга, коэффициент корреляции 0,24;
# в) WiiU показывает зависимость с коэффициентом корреляции 0,42.
#
#
# Можно сделать следующие выводы: стабильно высокую прибыль от продаж (по самым популярным платформам) получают те игры, которые имеют высокие рейтинги от критиков. Пользовательские отзывы оказывают влияние на продажи только на игры, размещенные на следующих платформах: 3DS и WiiU.

# %% [markdown]
# ### Распределение игр по жанрам

# %%
# посмотрим на табличку с количеством игр и суммарной выручкой по жанрам
display(actual_data.pivot_table(index='genre', aggfunc={'name':'count', 'total_sales':'sum'}).sort_values(by='total_sales', ascending=False))

# посмотрим на столбец с суммарной выручкой
actual_data.pivot_table(index='genre', aggfunc={'total_sales':'sum'}).sort_values(by='total_sales', ascending=False).describe()
# Out:
#               name  total_sales
# genre
# Action         766   322.000000
# Shooter        187   233.000000
# Sports         214   150.625000
# Role-Playing   292   145.875000
# Misc           155    62.843750
# Platform        74    42.625000
# Racing          85    39.906250
# Fighting        80    35.312500
# Adventure      245    23.640625
# Simulation      62    21.765625
# Strategy        56    10.078125
# Puzzle          17     3.169922
#        total_sales
# count    12.000000
# mean     90.937500
# std     101.125000
# min       3.169922
# 25%      23.171875
# 50%      41.265625
# 75%     147.062500
# max     322.000000

# %% [markdown]
# Видно, что самые прибыльные жанры это Action, Shooter, Sports, Role-Playing.
# - Action и Shooter - соревновательные жанры. Высокие продажи связаны с тем, что людям нравится соревноваться.
# - Sports - жанр имет такую же соревновательную природу, но к этому можно добавить элемент примерки на себя роли спортсмена, профессия которых высоко поощряется в обществе.
# - Role-Playing - жанр пользуется большим спросом, так как это отличный способ окунуться в необычную атмосферу, ассоциировать себя с любимым персонажем.
#
#
# Role-Playing, Sports, Action и Shooter можно считать жанрами с высокими продажами - их продажи превышают значения продаж всех остальных 75% жанров.
# Adventure, Simulation, Strategy и Puzzle можно считать группой с низкими продажами. Причины просты - высокий порог вхождения, необходимость большой вовлечённости и особого склада ума, а в случае с Simulation - необходимость докупать дорогостоящие игровые девайсы, чтобы добится погружения. Низкие показатели продаж связаны именно с этими причинами.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Исследовательский анализ показал, что с 1994 года идет бурный рост игровой индустрии - продажи непрестанно растут до 2008 года. Затем продажи начинают падать до момента выхода нового поколения консолей от мировых лидеров - PS4 и XOne в 2013 году.
#
# Затем мы посмотрели на изменение продаж со временем для самых прибыльных платформ, и выяснили, что платформа живёт 8 лет - 4 года она развивается и показывает постоянный прирост продаж, ещё четыре года спад продаж и стагнация. Исходя из этого, а также обнаруженной новой точки роста продаж, мы ещё больше сузили актуальный для нас период - 2013-2016 год, первая половина жизненного цикла консолей нового поколения.
#
# Посмотрели на продажи и их изменение по времени за актуальный период, посмотрели ящик с усами по каждой платформе.
#
# Изучили, как влияют отзывы пользователей и критиков на показатели продаж.
#
# Посмотрели на распределение игр по жанрам.

# %% [markdown]
# ## Портрет пользователя каждого региона

# %% [markdown]
# ### Самые популярные платформы (топ-5)

# %%
# выведем топ-5 платформ по суммарным продажам для регионов NA, EU, JP
for i in ['na_sales', 'eu_sales', 'jp_sales']:
    local_data = actual_data.pivot_table(index='platform', aggfunc={i:'sum'}).sort_values(by=i, ascending=False).head().reset_index()
    local_data['share'] = round(local_data[i] / local_data[i].sum(), 2) * 100
    display(local_data)
# Out:
#   platform   na_sales  share
# 0      PS4  108.75000   28.0
# 1     XOne   93.12500   24.0
# 2     X360   81.62500   21.0
# 3      PS3   63.50000   16.0
# 4      3DS   38.21875   10.0
#   platform    eu_sales  share
# 0      PS4  141.125000   42.0
# 1      PS3   67.812500   20.0
# 2     XOne   51.593750   15.0
# 3     X360   42.531250   13.0
# 4      3DS   30.953125    9.0
#   platform   jp_sales  share
# 0      3DS  67.812500   50.0
# 1      PS3  23.343750   17.0
# 2      PSV  18.593750   14.0
# 3      PS4  15.960938   12.0
# 4     WiiU  10.882812    8.0

# %% [markdown]
# Северная Америка и Европа в целом схожи - в топ-5 одни и те же платформы. Лидер продаж в обоих регионах это PS4, причём в Европе продажи по этой платформе выше. 2, 3 и 4 места различаются:
# - в Северной Америке в тройке лидеров ожидаемо оба поколения Xbox, на четвертом месте PS3;
# - в Европе - PS3 и Xbox.
# - замыкает топ в обоих регионах 3DS.
#
# Японский регион ожидаемо патриотичен. На первом месте 3DS (продажи почти такие же, как суммарно в Северной Америке и Европе). Продажи выше почти в 3 раза, чем у ближайшего преследователя. Со 2-го по 4-е место платформы от Sony: PS3, PSV, PS4. Замыкает топ WiiU.

# %% [markdown]
# ### Самые популярные жанры (топ-5)

# %%
# выведем топ-5 жанров по суммарным продажам для регионов NA, EU, JP
for i in ['na_sales', 'eu_sales', 'jp_sales']:
    local_data = actual_data.pivot_table(index='genre', aggfunc={i:'sum'}).sort_values(by=i, ascending=False).head().reset_index()
    local_data['share'] = round(local_data[i] / local_data[i].sum(), 2) * 100
    display(local_data)
# Out:
#           genre    na_sales  share
# 0        Action  126.062500   34.0
# 1       Shooter  109.750000   29.0
# 2        Sports   65.250000   17.0
# 3  Role-Playing   46.406250   12.0
# 4          Misc   27.484375    7.0
#           genre   eu_sales  share
# 0        Action  118.12500   36.0
# 1       Shooter   87.87500   27.0
# 2        Sports   60.53125   19.0
# 3  Role-Playing   36.96875   11.0
# 4        Racing   20.18750    6.0
#           genre   jp_sales  share
# 0  Role-Playing  51.031250   44.0
# 1        Action  40.500000   35.0
# 2          Misc   9.203125    8.0
# 3      Fighting   7.648438    7.0
# 4       Shooter   6.609375    6.0

# %% [markdown]
# Как и в случае с платформами, Северная Америка и Европа показали практически идентичную картину. Первые четыре места совпадают с выводами, которые получили при общей оценке распределения общих продаж по жанрам. На пятом месте по Северной Америке жанр Misc, в Европе - Racing.
#
# Япония снова отличается, ввиду своих культурных особенностей. На первом месте - Role-playing, на втором Action. После этого резкий провал по значения продаж и дальше по ниспадающей.

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
# выведем сводную таблицу суммарных продаж для регионов NA, EU, JP по рейтингу ESRB
for i in ['na_sales', 'eu_sales', 'jp_sales']:
    local_data = actual_data.pivot_table(index='rating', aggfunc={i:'sum'}).sort_values(by=i, ascending=False).reset_index()
    local_data['share'] = round(local_data[i] / local_data[i].sum(), 2) * 100
    display(local_data)
# Out:
#   rating   na_sales  share
# 0      M  165.25000   38.0
# 1     RP   89.43750   20.0
# 2      E   79.06250   18.0
# 3   E10+   54.25000   12.0
# 4      T   49.78125   11.0
#   rating  eu_sales  share
# 0      M  145.3750   37.0
# 1      E   83.3750   21.0
# 2     RP   78.9375   20.0
# 3   E10+   42.6875   11.0
# 4      T   41.9375   11.0
#   rating   jp_sales  share
# 0     RP  85.062500   60.0
# 1      T  20.593750   15.0
# 2      E  15.140625   11.0
# 3      M  14.109375   10.0
# 4   E10+   5.890625    4.0

# %% [markdown]
# Как и в предыдущих исследованиях, Северная Америка и Европа показывают скожую картину. Основную долю рынка составляют игры с рейтингом M. Это логично, т.к. все игры самых популярных жанров содержат сцены насилия, вид крови, и т.д. На втором месте стоят игры с рейтингом E и RP (доли продаж очень близки, поэтому можно поставить их на одну ступень). Это тоже логично - если у игры стоит рейтинг E или он пока не определён (RP), то продажам ничто не мешает - возрастной ценз отсутствует, отсюда и самый максимальный охват. На третьем месте стоят игры с рейтингом E10+ и T (доли продаж опять же очень близки).
#
# Для Японии большую долю рынка составляют игры с рейтингом RP - т.е. без рейтинга. Второе место занимают подростковые игры (рейтинг T). Третье место у жанров E и M (доли рынка близки), и в конце рейтинг E10+ с 4% рынка.

# %% [markdown]
# Построим график рейтинга ESRB по регионам.

# %%
# функция для построения графика рейтинга ESRB по регионам
def top_in_regions(groupby, region_sales, ax):
    top_region = actual_data.groupby(groupby).agg({region_sales: 'sum'}).sort_values(by=region_sales, ascending=False)[:5]
    region_dict = {'na_sales': 'North America Sales', 'eu_sales': 'Europe Sales', 'jp_sales': 'Japan Sales'}
    plot = top_region.plot(kind='bar', ec='black', title=region_dict[region_sales], ax=axes[ax], 
                   fontsize=18, rot=20)
    plot.legend(prop={'size':17})
    plot.set_xlabel('')
    plot.title.set_size(20)
 
fig, axes = plt.subplots(1, 3, figsize=(25,5))
plt.ylim(0, 180)
 
top_in_regions('rating', 'na_sales', 0)
top_in_regions('rating', 'eu_sales', 1)
top_in_regions('rating', 'jp_sales', 2)

# %% [markdown]
# ### Вывод

# %% [markdown]
# Как мы увидели, портреты пользователей из Северной Америки и Европы можно в целом объединить в один общий. Этот пользователь характерен следующим:
# - Предпочитает консоли двух ведущих производителей. В первую очередь - последнего поколения.
# - Любит соревновательные многопользовательские жанры и Role-Playing.
# - Приобретает игры с рейтингом M, но и остальные рейтинги имеют хорошие доли рынка.
#
# Японский пользователь совершенно отличается. Особенности заключаются в следующем:
# - Предпочитает игры на японских платформах.
# - Не гонится за последними поколениями игр.
# - Больше всего предпочитает жанр Role-Playing, Action и относительно немного Fighting, Shooter и Misc.
# - Насилие по ESRB не в приоритете.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Гипотеза 1: "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые"

# %% [markdown]
# Сформируем нулевую и альтернативную гипотезы:
#
# H0: средние пользовательские рейтинги указанных платформ равны
# H1: средние пользовательские рейтинги указанных платформ отличаются

# %%
# подготовим выборки
sample_1 = actual_data.query('(user_score > 0) and (platform == "XOne")')['user_score']
sample_2 = actual_data.query('(user_score > 0) and (platform == "PC")')['user_score']

# оценим визуально распределения выборок
sample_1.hist(bins=30)
plt.show()
sample_2.hist(bins=30)
plt.show()

# посчитаем дисперсии выборок
var1 = np.var(sample_1)
var2 = np.var(sample_2)

# оценим размер выборок
len1 = len(sample_1)
len2 = len(sample_2)

# выведем рассчитанные показатели на экран
print(f'Выборки 1 и 2 имеют дисперсии {var1} и {var2} соответственно')
print(f'Выборки 1 и 2 имеют размеры {len1} и {len2} соответственно')
# Out:
# Выборки 1 и 2 имеют дисперсии 1.896484375 и 3.015625 соответственно
# Выборки 1 и 2 имеют размеры 182 и 155 соответственно

# %% [markdown]
# Распределение выборок  напоминает нормальное, поэтому для проверки гипотез применим критерий Стьюдента. С учётом размеров выборок,  уровень статистической значимости примем равным 0,01. С учётом значений дисперсии можно принять значение equal_var при проведении проверки равным False.

# %%
# задаём критический уровень статистической значимости
alpha = 0.01

# проводим тест
results = st.ttest_ind(sample_1, sample_2, equal_var = False)

# выводим результат теста
print('p-значение: ', results.pvalue)

# проверяем гипотезу
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение:  0.14414956265829446
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Нулевая гипотеза подтверждена. Средние рейтинги по этим платформам равны в рамках статистической значимости. Проверим относительную разницу в рейтингах:

# %%
print('Средний пользовательский рейтинг на платформе Xbox One: {:.2f}'.format(sample_1.mean()))
print('Средний пользовательский рейтинг на платформе PC: {:.2f}'.format(sample_2.mean()))
print('Наибольший из двух средних отличается от наименьшего на {:.2%}'.format(abs(sample_1.mean() - sample_2.mean())/max(sample_1.mean(), sample_2.mean())))
# Out:
# Средний пользовательский рейтинг на платформе Xbox One: 6.52
# Средний пользовательский рейтинг на платформе PC: 6.27
# Наибольший из двух средних отличается от наименьшего на 3.89%

# %% [markdown]
# ### Гипотеза 2: "Средние пользовательские рейтинги жанров Action и Sports разные"

# %% [markdown]
# Сформируем нулевую и альтернативную гипотезы:
#
# H0: средние пользовательские рейтинги указанных жанров одинаковые
# H1: средние пользовательские рейтинги указанных жанров разные

# %%
# подготовим выборки
sample_1 = actual_data.query('(user_score > 0) and (genre == "Action")')['user_score']
sample_2 = actual_data.query('(user_score > 0) and (genre == "Sports")')['user_score']

# оценим визуально распределение данных
sample_1.hist(bins=30)
plt.show()
sample_2.hist(bins=30)
plt.show()

# посчитаем дисперсии выборок
var1 = np.var(sample_1)
var2 = np.var(sample_2)

# оценим размер выборок
len1 = len(sample_1)
len2 = len(sample_2)

# выведем рассчитанные показатели на экран 
print(f'Выборки 1 и 2 имеют дисперсии {var1} и {var2} соответственно')
print(f'Выборки 1 и 2 имеют размеры {len1} и {len2} соответственно')
# Out:
# Выборки 1 и 2 имеют дисперсии 1.7646484375 и 3.16015625 соответственно
# Выборки 1 и 2 имеют размеры 389 и 160 соответственно

# %% [markdown]
# Распределение выборок  напоминает нормальное, поэтому для проверки гипотез применим критерий Стьюдента. С учётом размеров выборок,  уровень статистической значимости примем равным 0,01. С учётом значений дисперсии можно принять значение equal_var при проведении проверки равным False.

# %%
# задаём критический уровень статистической значимости
alpha = 0.01

# проводим тест
results = st.ttest_ind(sample_1, sample_2, equal_var = False)

# выводим результат теста
print('p-значение: ', results.pvalue)

# проверяем гипотезу
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение:  1.5834781245696843e-20
# Отвергаем нулевую гипотезу

# %% [markdown]
# Нулевая гипотеза отвергнута, следовательно мы принимаем альтернативную гипотезу - средние рейтинги этих жанров не равны в рамках статистической значимости. Таким образом, гипотеза №2 также подтверждена. Проверим относительную разницу в рейтингах.

# %%
print('Средний пользовательский рейтинг жанра Action: {:.2f}'.format(sample_1.mean()))
print('Средний пользовательский рейтинг жанра Sports: {:.2f}'.format(sample_2.mean()))
print('Наибольший из двух средних отличается от наименьшего на {:.2%}'.format(abs(sample_1.mean() - sample_2.mean())/max(sample_1.mean(), sample_2.mean())))
# Out:
# Средний пользовательский рейтинг жанра Action: 6.84
# Средний пользовательский рейтинг жанра Sports: 5.24
# Наибольший из двух средних отличается от наименьшего на 23.41%

# %% [markdown]
# Разница действительно существенная.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Мы провели проверку предложенных нам гипотез и установили, что гипотеза №1 верна, и средние пользовательские рейтинги для платформ Xbox One и PC равны в рамках статистической значимости. Относительная разница между средними составила всего 3,89%.
#
# Гипотеза №2 также верна - средние рейтинги жанров Action и Sports отличаются. Средний рейтинг жанра Action больше на 23,41%.
#
# Для проверки гипотез мы использовали критерий Стьюдента. Его применение мы обосновали, т.к. первоначально провели изучение сравниваемых выборок и оценку их дисперсий и размерности.

# %% [markdown]
# ## Вывод

# %% [markdown]
# При планировании кампании на 2017 год нам нужно учесть следующее:
#
# Для европейского и североамериканского сегмента нашего магазина нужно сосредоточиться на платформах, активно набирающих обороты - это PS4 и XOne. При этом следующие платформы также заслуживают внимания:
# - платформа PC;
# - платформы, которые уже не такие прибыльные, но все ещё показывают неплохие продажи: PS3, X360, 3DS, WiiU, PSV.
# Жанры, на которые необходимо обратить внимание:
# - Action
# - Shooter
# - Sports
# - Role-Playing
# - Racing
# При выборе отдельных игр для рекламы можно не опасаться строгих возрастных рейтингов - у них высокие продажи, игроков этих регионов они не пугают.
#
# Для японского сегмента всё не так просто. Основную ставку делаем на платформу DS - у неё самые высокие продажи. И аккуратно выбираем игры для продвижения на платформе PS4 - она хоть и растёт в целом, но в данном регионе продажи не слишком высокие.
# Основные жанры, на которые стоит обратить внимание в этом сегменте:
# - Role-Playing;
# - Action.
# При выборе отдельных игр для рекламы придётся опасаться жёстких возрастных рейтингов по версии ESRB - у них малая доля рынка, игроков эти игры мало интересуют. У игр без рейтинга самая высокая доля продаж.
#
# При подборе конкретных игр для платформ PS4 и XOne стоит опираться только на оценки критиков. Как мы увидели, для этих платформ именно рейтинг критиков имеет влияние на продажи.
#
# Для платформы 3DS уже стоит начинать прислушиваться к мнению пользователей - там влияние пользовательского рейтинга на продажи существенно.
